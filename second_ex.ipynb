# %%
import requests as rq
from utils import read_bills_without_normalize
import os
import regex
from elasticsearch import Elasticsearch
from pathlib import Path

# %% [markdown]
# # Check if ES works

# %%
es_url = "http://localhost:9200"
es = Elasticsearch(es_url)

# %%
es.info()
# Out:
# ObjectApiResponse({'name': '35f5cbf1a125', 'cluster_name': 'docker-cluster', 'cluster_uuid': 'ZW8ilXXfTOS_RXihBz65Tg', 'version': {'number': '8.4.3', 'build_flavor': 'default', 'build_type': 'docker', 'build_hash': '42f05b9372a9a4a470db3b52817899b99a76ee73', 'build_date': '2022-10-04T07:17:24.662462378Z', 'build_snapshot': False, 'lucene_version': '9.3.0', 'minimum_wire_compatibility_version': '7.17.0', 'minimum_index_compatibility_version': '7.0.0'}, 'tagline': 'You Know, for Search'})

# %% [markdown]
# # Constants

# %%
es_analyzer = "polish_es_analyzer"
es_index = "bills"

# %% [markdown]
# # Create analyzer

# %%
resp = rq.delete(url = f"{es_url}/{es_index}")
resp.json()
# Out:
# {'acknowledged': True}

# %%
rq.post(url = f"{es_url}/{es_index}/_refresh")
# Out:
# <Response [404]>

# %%
# ref https://www.elastic.co/guide/en/elasticsearch/reference/current/analyzer.html
# it looks like according to the doc that we have to create analyzer under specific index 
response = rq.put(
    url = f"{es_url}/{es_index}",
    json = {
    "settings":{
        "analysis":{
            "analyzer":{
                f"{es_analyzer}":{ 
                    "type":"custom",
                    "tokenizer":"standard",
                    "filter":[
                        "lowercase",
                        "synonym",
                        "morfologik_stem"
                    ]
                }
            },
            "filter":{
                "synonym":{
                    "type": "synonym",
                    "expand": True, # we don't want the target mapping to be only the first word ref https://www.elastic.co/guide/en/elasticsearch/reference/current/analysis-synonym-tokenfilter.html
                    "synonyms": [ 
                        "kpk => kodeks postępowania karnego",
                        "kpc => kodeks postępowania cywilnego",
                        "kk => kodeks karny",
                        "kc => kodeks cywilny"
                    ]
                }
            }
        }
    },
    "mappings":{
        "properties":{
            "text": { # this need to be same as filed in json to which we are gonna to load data!!!!!
                "type": "text",
                "analyzer": f"{es_analyzer}", 
            }
        }
    }
})

# %%
response.json()
# Out:
# {'acknowledged': True, 'shards_acknowledged': True, 'index': 'bills'}

# %%
response = rq.get(
    url=f"{es_url}/{es_index}/_analyze",
    json={
        "text": "kpc i kpk i kk i kc",
        "analyzer": f"{es_analyzer}"
    }
)
response.json()
# Out:
# {'tokens': [{'token': 'kodeks',
#    'start_offset': 0,
#    'end_offset': 3,
#    'type': 'SYNONYM',
#    'position': 0},
#   {'token': 'i',
#    'start_offset': 4,
#    'end_offset': 5,
#    'type': '<ALPHANUM>',
#    'position': 1},
#   {'token': 'postępowanie',
#    'start_offset': 4,
#    'end_offset': 5,
#    'type': 'SYNONYM',
#    'position': 1},
#   {'token': 'postępować',
#    'start_offset': 4,
#    'end_offset': 5,
#    'type': 'SYNONYM',
#    'position': 1},
#   {'token': 'cywilny',
#    'start_offset': 6,
#    'end_offset': 9,
#    'type': 'SYNONYM',
#    'position': 2},
#   {'token': 'kodeks',
#    'start_offset': 6,
#    'end_offset': 9,
#    'type': 'SYNONYM',
#    'position': 2},
#   {'token': 'i',
#    'start_offset': 10,
#    'end_offset': 11,
#    'type': '<ALPHANUM>',
#    'position': 3},
#   {'token': 'postępowanie',
#    'start_offset': 10,
#    'end_offset': 11,
#    'type': 'SYNONYM',
#    'position': 3},
#   {'token': 'postępować',
#    'start_offset': 10,
#    'end_offset': 11,
#    'type': 'SYNONYM',
#    'position': 3},
#   {'token': 'karny',
#    'start_offset': 12,
#    'end_offset': 14,
#    'type': 'SYNONYM',
#    'position': 4},
#   {'token': 'kodeks',
#    'start_offset': 12,
#    'end_offset': 14,
#    'type': 'SYNONYM',
#    'position': 4},
#   {'token': 'i',
#    'start_offset': 15,
#    'end_offset': 16,
#    'type': '<ALPHANUM>',
#    'position': 5},
#   {'token': 'karny',
#    'start_offset': 15,
#    'end_offset': 16,
#    'type': 'SYNONYM',
#    'position': 5},
#   {'token': 'kodeks',
#    'start_offset': 17,
#    'end_offset': 19,
#    'type': 'SYNONYM',
#    'position': 6},
#   {'token': 'cywilny',
#    'start_offset': 17,
#    'end_offset': 19,
#    'type': 'SYNONYM',
#    'position': 7}]}

# %% [markdown]
# # Read bills without normalization

# %%
current_dir = os.getcwd()
bills_dict = read_bills_without_normalize(f"{current_dir}/data/first_ex_data/ustawy")

# %%
len(bills_dict.values())
# Out:
# 1178

# %%
bills_dict["1999_700"]
# Out:
# '\n\n\n\nDz.U. z 1999 r. Nr 63, poz. 700 \n                                       \n                                                                               \n                                                                               \n                                                                               \n                                                                               \n                                    USTAWA\n                            z dnia 8 lipca 1999 r.\n                                       \n            o zmianie ustawy o powszechnym ubezpieczeniu zdrowotnym\n                                       \n                                       \n                                    Art. 1.\nW ustawie z dnia 6 lutego 1997 r. o powszechnym ubezpieczeniu zdrowotnym (Dz.U.\nNr 28, poz. 153 i Nr 75, poz. 468, z 1998 r. Nr 117, poz. 756, Nr 137, poz.\n887, Nr 144, poz. 929 i Nr 162, poz. 1116 oraz z 1999 r. Nr 45, poz. 439 i Nr\n49, poz. 483), w art. 169c w ust. 2 wyrazy "30 czerwca 1999 r." zastępuje się\nwyrazami "31 grudnia 1999 r.".\n                                    Art. 2.\nŚrodki finansowe przekazane właściwym Kasom Chorych w okresie od dnia 1 lipca\n1999 r. do dnia wejścia w życie niniejszej ustawy zalicza się na poczet kwot\nprzewidzianych w planie finansowym sporządzonym przez Pełnomocnika Rządu do\nSpraw Wprowadzenia Ubezpieczenia Zdrowotnego.\n                                    Art. 3.\nUstawa wchodzi w życie z dniem ogłoszenia.\n'

# %% [markdown]
# # Load data to ES index

# %%
# for file_id, file_content in bills_dict.items():
#     response = rq.delete(url = f"{es_url}/{es_index}/_doc/{file_id}")

# %%
for file_id, file_content in bills_dict.items():
    response = rq.put(
        url = f"{es_url}/{es_index}/_doc/{file_id}",
        json = {
            "text": f"{file_content}"
        })
#     print(response.json())
#     if (response.json()['acknowledged'] is not True):
#         print("Error")
#     es.create(index=es_index, id=file_id, document={"text": file_content})
# Out:
# {'_index': 'bills', '_id': '2001_874', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 0, '_primary_term': 1}
# {'_index': 'bills', '_id': '1996_583', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 1, '_primary_term': 1}
# {'_index': 'bills', '_id': '2003_1853', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 2, '_primary_term': 1}
# {'_index': 'bills', '_id': '1997_753', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 3, '_primary_term': 1}
# {'_index': 'bills', '_id': '2000_440', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 4, '_primary_term': 1}
# {'_index': 'bills', '_id': '2004_1375', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 5, '_primary_term': 1}
# {'_index': 'bills', '_id': '2003_597', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 6, '_primary_term': 1}
# {'_index': 'bills', '_id': '2003_1884', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 7, '_primary_term': 1}
# {'_index': 'bills', '_id': '2001_1196', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 8, '_primary_term': 1}
# {'_index': 'bills', '_id': '1997_592', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 9, '_primary_term': 1}
# {'_index': 'bills', '_id': '2001_21', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 10, '_primary_term': 1}
# {'_index': 'bills', '_id': '2000_695', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 11, '_primary_term': 1}
# {'_index': 'bills', '_id': '1995_681', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 12, '_primary_term': 1}
# {'_index': 'bills', '_id': '2004_2456', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 13, '_primary_term': 1}
# {'_index': 'bills', '_id': '2000_118', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 14, '_primary_term': 1}
# {'_index': 'bills', '_id': '2003_1304', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 15, '_primary_term': 1}
# {'_index': 'bills', '_id': '2001_1380', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 16, '_primary_term': 1}
# {'_index': 'bills', '_id': '2004_1956', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 17, '_primary_term': 1}
# {'_index': 'bills', '_id': '2001_1545', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 18, '_primary_term': 1}
# {'_index': 'bills', '_id': '1996_636', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 19, '_primary_term': 1}
# {'_index': 'bills', '_id': '2004_1981', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 20, '_primary_term': 1}
# {'_index': 'bills', '_id': '1994_294', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 21, '_primary_term': 1}
# {'_index': 'bills', '_id': '1996_622', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 22, '_primary_term': 1}
# {'_index': 'bills', '_id': '2003_2037', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 23, '_primary_term': 1}
# {'_index': 'bills', '_id': '2000_1009', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 24, '_primary_term': 1}
# {'_index': 'bills', '_id': '2004_1598', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 25, '_primary_term': 1}
# {'_index': 'bills', '_id': '2004_879', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 26, '_primary_term': 1}
# {'_index': 'bills', '_id': '2004_892', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 27, '_primary_term': 1}
# {'_index': 'bills', '_id': '1996_352', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 28, '_primary_term': 1}
# {'_index': 'bills', '_id': '2004_886', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 29, '_primary_term': 1}
# {'_index': 'bills', '_id': '2003_2221', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 30, '_primary_term': 1}
# {'_index': 'bills', '_id': '2004_2708', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 31, '_primary_term': 1}
# {'_index': 'bills', '_id': '2001_733', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 32, '_primary_term': 1}
# {'_index': 'bills', '_id': '1999_936', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 33, '_primary_term': 1}
# {'_index': 'bills', '_id': '1996_409', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 34, '_primary_term': 1}
# {'_index': 'bills', '_id': '2001_726', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 35, '_primary_term': 1}
# {'_index': 'bills', '_id': '2002_1067', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 36, '_primary_term': 1}
# {'_index': 'bills', '_id': '2004_887', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 37, '_primary_term': 1}
# {'_index': 'bills', '_id': '1996_347', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 38, '_primary_term': 1}
# {'_index': 'bills', '_id': '1997_154', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 39, '_primary_term': 1}
# {'_index': 'bills', '_id': '2004_893', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 40, '_primary_term': 1}
# {'_index': 'bills', '_id': '2003_1067', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 41, '_primary_term': 1}
# {'_index': 'bills', '_id': '1997
'_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 1168, '_primary_term': 1}
# {'_index': 'bills', '_id': '2001_1366', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 1169, '_primary_term': 1}
# {'_index': 'bills', '_id': '2003_1123', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 1170, '_primary_term': 1}
# {'_index': 'bills', '_id': '2002_945', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 1171, '_primary_term': 1}
# {'_index': 'bills', '_id': '1997_776', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 1172, '_primary_term': 1}
# {'_index': 'bills', '_id': '2004_1378', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 1173, '_primary_term': 1}
# {'_index': 'bills', '_id': '1995_471', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 1174, '_primary_term': 1}
# {'_index': 'bills', '_id': '2003_1692', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 1175, '_primary_term': 1}
# {'_index': 'bills', '_id': '1995_1', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 1176, '_primary_term': 1}
# {'_index': 'bills', '_id': '1997_945', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 1177, '_primary_term': 1}

# %% [markdown]
# # Determine the number of legislative acts containing the word ustawa (in any form)

# %%
resp = rq.get(
        url = f"{es_url}/{es_index}/_search",
        json = {
            "query": {
                "match": {
                    "text": {
                        "query": "ustawa"
                    }
                }
            }
        }
)

# %%
resp.json()['hits']['total']['value']
# Out:
# 1178

# %% [markdown]
# # Determine the number of occurrences of the word ustawa by searching for this particular form, including the other inflectional forms.

# %%
resp = es.termvectors( 
    index=es_index,
    id = "1999_700",
    fields=["text"],
    term_statistics=True
)

# %%
resp['term_vectors']['text']['terms']['ustawa']['ttf']
# Out:
# 24934

# %%
response = rq.get(
    url=f"{es_url}/{es_index}/_termvectors/1999_700",
    json={
        "fields": ["text"],
        "term_statistics": True
    }
)

response.json()["term_vectors"]["text"]["terms"]["ustawa"]['ttf']
# Out:
# 24934

# %% [markdown]
# # Determine the number of occurrences of the word ustaw by searching for this particular form, including the other inflectional forms.

# %%
response = rq.get(
    url=f"{es_url}/{es_index}/_analyze",
    json={
        "text": "ustaw",
        "analyzer": f"{es_analyzer}"
    }
)

response.json()
# Out:
# {'tokens': [{'token': 'ustawa',
#    'start_offset': 0,
#    'end_offset': 5,
#    'type': '<ALPHANUM>',
#    'position': 0},
#   {'token': 'ustawić',
#    'start_offset': 0,
#    'end_offset': 5,
#    'type': '<ALPHANUM>',
#    'position': 0}]}

# %%
response = rq.get(
    url=f"{es_url}/{es_index}/_termvectors/1993_599", # text under this ID must contains words ustawa and ustawić!!
    json={
        "fields": ["text"],
        "term_statistics": True
    }
)

response.json()["term_vectors"]["text"]["terms"]['ustawa']['ttf'] + response.json()["term_vectors"]["text"]["terms"]['ustawić']['ttf']
# Out:
# 25847

# %% [markdown]
# # Determine the number of legislative acts containing the words kodeks postępowania cywilnego in the specified order, but in any inflection form.

# %%
es.search(index=es_index, query={"match_phrase" : {"text": {"query" : "kodeks postępowania cywilnego"}}})['hits']['total']['value']
# Out:
# 99

# %%
response = rq.get(
    url=f"{es_url}/{es_index}/_search",
    json={
        "query": {
            "match_phrase": {
                "text": {
                    "query": "kodeks postępowania cywilnego"
                }
            }
        }
    }
)

response.json()['hits']['total']['value']
# Out:
# 99

# %% [markdown]
# # Determine the number of legislative acts containing the words wchodzi w życie (in any form) allowing for up to 2 additional words in the searched phrase.

# %%
es.search(index=es_index, query={"match_phrase": {"text": {"query" :"wchodzi w życie", "slop": 2}}})['hits']['total']['value']
# Out:
# 1174

# %%
response = rq.get(
    url=f"{es_url}/{es_index}/_search",
    json={
        "query": {
            "match_phrase": {
                "text": {
                    "query": "wchodzi w życie",
                    "slop" : 2
                }
            }
        }
    }
)

response.json()['hits']['total']['value']
# Out:
# 1174

# %% [markdown]
# # Determine the 10 documents that are the most relevant for the phrase konstytucja.

# %%
res = es.search(index=es_index, query={'match': {'text': {'query' :'konstytucja'}}}, size=10)['hits']['hits']
for i in res:
    print(f"{i['_id'] :<9} | {i['_score']}")
# Out:
# 1997_629  | 6.867635
# 2000_443  | 6.662749
# 1997_604  | 6.6320543
# 1996_350  | 6.626803
# 1997_642  | 6.251624
# 2001_23   | 6.0579295
# 1996_199  | 5.928016
# 1999_688  | 5.8496947
# 2001_1082 | 5.466536
# 1997_681  | 5.466536

# %%
response = rq.get(
    url=f"{es_url}/{es_index}/_search",
    json={
        "query": {
            "match": {
                "text": {
                    "query": "konstytucja"
                }
            }
        },
        "size": 10
    }
)


res_list = response.json()['hits']['hits']
for i in res_list:
    print(f"{i['_id'] :<9} | {i['_score']}")
# Out:
# 1997_629  | 6.867635
# 2000_443  | 6.662749
# 1997_604  | 6.6320543
# 1996_350  | 6.626803
# 1997_642  | 6.251624
# 2001_23   | 6.0579295
# 1996_199  | 5.928016
# 1999_688  | 5.8496947
# 2001_1082 | 5.466536
# 1997_681  | 5.466536

# %% [markdown]
# # Print the excerpts containing the word konstytucja (up to three excerpts per document) from the previous task.

# %%
response = rq.get(
    url=f"{es_url}/{es_index}/_search",
    json={
        "query": {
            "match": {
                "text": {
                    "query": "konstytucja"
                }
            }
        },
        "highlight": { # https://www.elastic.co/guide/en/elasticsearch/reference/current/highlighting.html
            "fields": {
                "text": {
                    "number_of_fragments": 3
                }
            },
        },
        "size": 10
    }
)

resp_list = response.json()['hits']['hits']
for bill in resp_list:
    print(f"{bill['_id'] :<9} | {bill['_score']}")
    for excerpt in bill["highlight"]['text']:
        print(excerpt)
        print("-------------------------")
    print('||||||||||||||||||||||||||')
# Out:
# 1997_629  | 6.867635
# o zmianie ustawy konstytucyjnej o trybie przygotowania
#            i uchwalenia <em>Konstytucji</em> Rzeczypospolitej
# -------------------------
# W ustawie  konstytucyjnej z  dnia 23 kwietnia 1992 r. o trybie przygotowania i
# uchwalenia <em>Konstytucji</em>
# -------------------------
# Do zgłoszenia projektu <em>Konstytucji</em> załącza się wykaz
#                 obywateli popierających zgłoszenie
# -------------------------
# ||||||||||||||||||||||||||
# 2000_443  | 6.662749
# umowy międzynarodowej i nie wypełnia przesłanek określonych w art. 89
#      ust. 1 lub art. 90 <em>Konstytucji</em>
# -------------------------
# międzynarodowej lub załącznika nie
#      wypełnia przesłanek określonych w art. 89 ust. 1 lub art. 90 <em>Konstytucji</em>
# -------------------------
# co do zasadności wyboru
#   trybu ratyfikacji umowy międzynarodowej, o którym mowa w art. 89 ust. 2
#   <em>Konstytucji</em>
# -------------------------
# ||||||||||||||||||||||||||
# 1997_604  | 6.6320543
# Jeżeli Trybunał Konstytucyjny wyda orzeczenie o sprzeczności celów partii
#    politycznej z <em>Konstytucją</em>
# -------------------------
# Jeżeli Trybunał Konstytucyjny wyda orzeczenie o sprzeczności z <em>Konstytucją</em>
#    celów lub działalności
# -------------------------
# Ciężar udowodnienia niezgodności z <em>Konstytucją</em> spoczywa
#                 na wnioskodawcy, który w tym
# -------------------------
# ||||||||||||||||||||||||||
# 1996_350  | 6.626803
# Za naruszenie <em>Konstytucji</em> lub ustawy, w związku z zajmowanym
#               stanowiskiem lub w zakresie
# -------------------------
# W zakresie określonym w art. 107 <em>Konstytucji</em> odpowiedzialność przed
#            Trybunałem Stanu ponoszą
# -------------------------
# Członkowie Rady Ministrów ponoszą odpowiedzialność przed Trybunałem
#            Stanu za naruszenie <em>Konstytucji</em>
# -------------------------
# ||||||||||||||||||||||||||
# 1997_642  | 6.251624
# wnioskami o:
#              1) stwierdzenie zgodności ustaw i umów międzynarodowych z
#                <em>Konstytucją</em>
# -------------------------
# stwierdzenie zgodności przepisów prawa wydawanych przez
#                centralne organy państwowe, z <em>Konstytucją</em>
# -------------------------
# ratyfikowanymi
#                umowami międzynarodowymi i ustawami,
#              4) stwierdzenie zgodności z <em>Konstytucją</em>
# -------------------------
# ||||||||||||||||||||||||||
# 2001_23   | 6.0579295
# W Dzienniku Ustaw Rzeczypospolitej Polskiej, zwanym dalej "Dziennikiem
#   Ustaw", ogłasza się:
#    1) <em>Konstytucję</em>
# -------------------------
# akty prawne dotyczące:
#    1) stanu wojny i zawarcia pokoju,
#    2) referendum zatwierdzającego zmianę <em>Konstytucji</em>
# -------------------------
# ministra, któremu Sejm wyraził wotum nieufności,
#      h) powoływania lub odwoływania na określone w <em>Konstytucji</em>
# -------------------------
# ||||||||||||||||||||||||||
# 1996_199  | 5.928016
# 2c i art. 9-11 ustawy konstytucyjnej z dnia 23 kwietnia
# 1992 r. o trybie przygotowania i uchwalenia <em>Konstytucji</em>
# -------------------------
# Prezydent Rzeczypospolitej Polskiej zarządza poddanie <em>Konstytucji</em> pod referendum
#    w trybie określonym
# -------------------------
# Przyjęcie w referendum <em>Konstytucji</em> następuje wówczas, gdy opowiedziała
#    się za nią większość biorących
# -------------------------
# ||||||||||||||||||||||||||
# 1999_688  | 5.8496947
# postępowania w sprawie wykonywania inicjatywy
# ustawodawczej przez obywateli, o której mowa w art. 118 ust. 2 <em>Konstytucji</em>
# -------------------------
# Projekt ustawy nie może dotyczyć spraw, dla których <em>Konstytucja</em>
# Rzeczypospolitej Polskiej zastrzega wyłączną
# -------------------------
# Projekt ustawy wniesiony do Marszałka Sejmu powinien odpowiadać wymogom
#   zawartym w <em>Konstytucji</em> i Regulaminie
# -------------------------
# ||||||||||||||||||||||||||
# 2001_1082 | 5.466536
# Krajowa Rada Sądownictwa, zwana dalej "Radą", realizuje cele określone w
#   <em>Konstytucji</em> Rzeczypospolitej
# -------------------------
# ) podejmuje uchwały w sprawach wystąpienia do Trybunału Konstytucyjnego o
#      zbadanie zgodności z <em>Konstytucją</em>
# -------------------------
# ||||||||||||||||||||||||||
# 1997_681  | 5.466536
# Rzecznik Praw Dziecka, zwany dalej Rzecznikiem, stoi na straży praw dziecka
#   określonych w <em>Konstytucji</em>
# -------------------------
# uroczyście, że przy wykonywaniu powierzonych mi obowiązków
#      Rzecznika Praw Dziecka dochowam wierności <em>Konstytucji</em>
# -------------------------
# ||||||||||||||||||||||||||
